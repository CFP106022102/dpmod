# %%
# %pylab inline
import dpmod
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mat = dpmod.Material()

# %%
mat.table()
# Out:
# |   # | Name    |
# |-----+---------|
# |   0 | Lorentz |

# %%
mat.table(0)
# Out:
# |   # | Parameter   |   Value |
# |-----+-------------+---------|
# |   0 | Amp.        |      10 |
# |   1 | E0          |      11 |
# |   2 | Damping     |       1 |

# %%
mat.add()

# %%
mat.table()
# Out:
# |   # | Name    |
# |-----+---------|
# |   0 | Lorentz |
# |   1 | Lorentz |

# %%
mat.plot()

# %%
mat.table(1)
# Out:
# |   # | Parameter   |   Value |
# |-----+-------------+---------|
# |   0 | Amp.        |      10 |
# |   1 | E0          |      11 |
# |   2 | Damping     |       1 |

# %%
mat.table()
# Out:
# |   # | Name    |
# |-----+---------|
# |   0 | Lorentz |
# |   1 | Lorentz |

# %%
mat.add(mod=dpmod.Lorentz(E0=3))

# %%
mat.table()
# Out:
# |   # | Name    |
# |-----+---------|
# |   0 | Lorentz |
# |   1 | Lorentz |
# |   2 | Lorentz |

# %%
mat.delete()

# %%
mat.table()
# Out:
# |   # | Name    |
# |-----+---------|
# |   0 | Lorentz |
# |   1 | Lorentz |

# %%
mat.delete(0)

# %%
mat.table()
# Out:
# |   # | Name    |
# |-----+---------|
# |   0 | Lorentz |

# %%
mat = dpmod.Material(E=np.linspace(1,20,1000))

# %%
mat.plot()

# %%
mat.add(mod=dpmod.Lorentz(E0=18))

# %%
mat.plot()
